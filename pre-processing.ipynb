# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("captcha28.png",1)

plt.imshow(image)

# %%
threshold , bw = cv2.threshold(image,0.01,10**9,cv2.THRESH_BINARY)
plt.imshow(bw)

# %%
image3 = bw[10:,:25]
plt.imshow(image3)

# %%
# cv2.imwrite("D:\\Pyhton Programs\\Projects\\ML Captcha\\dataset\\A\\10.png",image3)
# Out:
# True
